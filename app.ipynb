# %%
import streamlit as st
import joblib
import numpy as np

# Load the model
@st.cache_resource
def load_model():
    return joblib.load("multiclass_classification_model.pkl")

model = load_model()

# App layout
st.set_page_config(page_title="🎓 Predict Academic Outcome", layout="centered")
st.title("🎓 Predict Academic Outcome")
st.markdown("""
This app predicts whether a student is likely to **Graduate**, **Dropout**, or **Remain Enrolled** 
based on key academic and personal information.
""")

# Form for user input
with st.form("Academic Outcome Prediction Form"):
    col1, col2, col3 = st.columns(3)

    with col1:
        Course = st.selectbox(
            "Select Course",
            ["Architecture", "Computer Science", "Physics", "Accounting", "Civil Engineering"]
        )
        Displaced = st.selectbox("Displaced", ["No", "Yes"])
        Special_Needs = st.selectbox("Educational Special Needs", ["No", "Yes"])
        Tuition = st.selectbox("Tuition Fees Up to Date", ["No", "Yes"])
        Gender = st.selectbox("Gender", ["Male", "Female"])
    
    with col2:
        Scholarship = st.selectbox("Scholarship Holder", ["No", "Yes"])
        Age_at_enrollment = st.number_input("Age at Enrollment", min_value=16, max_value=90, value=18)
        Sem1_Enrolled = st.number_input("Curricular Units 1st Sem (Enrolled)", min_value=0, value=6)
        Sem1_Approved = st.number_input("Curricular Units 1st Sem (Approved)", min_value=0, value=5)
        Sem1_Grade = st.number_input("Curricular Units 1st Sem (Grade)", min_value=0.0, max_value=20.0, value=12.0)
    
    with col3:
        Sem2_Enrolled = st.number_input("Curricular Units 2nd Sem (Enrolled)", min_value=0, value=6)
        Sem2_Approved = st.number_input("Curricular Units 2nd Sem (Approved)", min_value=0, value=5)
        Sem2_Grade = st.number_input("Curricular Units 2nd Sem (Grade)", min_value=0.0, max_value=20.0, value=12.0)

    submitted = st.form_submit_button("Predict Outcome")

# Prediction section
if submitted:
    # Encode categorical variables
    course_map = {
        "Architecture": 0,
        "Computer Science": 1,
        "Physics": 2,
        "Accounting": 3,
        "Civil Engineering": 4
    }

    displaced_val = 1 if Displaced == "Yes" else 0
    special_needs_val = 1 if Special_Needs == "Yes" else 0
    tuition_val = 1 if Tuition == "Yes" else 0
    gender_val = 1 if Gender == "Female" else 0  # Assuming Female=1, Male=0
    scholarship_val = 1 if Scholarship == "Yes" else 0

    # Arrange features in the same order the model expects
    features = np.array([[
        course_map[Course], displaced_val, special_needs_val, tuition_val,
        gender_val, scholarship_val, Age_at_enrollment,
        Sem1_Enrolled, Sem1_Approved, Sem1_Grade,
        Sem2_Enrolled, Sem2_Approved, Sem2_Grade
    ]])

    # Make prediction
    prediction = model.predict(features)[0]

    # Map prediction to label
    label_map = {0: "Enrolled", 1: "Graduate", 2: "Dropout"}
    predicted_label = label_map.get(prediction, "Unknown")

    # Display result
    st.success(f"🎯 Predicted Academic Outcome: **{predicted_label}**")
# Out:
# 2025-11-07 10:57:23.472 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:23.982
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\Teninlanimi\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-11-07 10:57:23.983 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:23.984 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:24.481 Thread 'Thread-3': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:24.485 Thread 'Thread-3': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.035 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.037 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.038 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.039 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.040 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.043 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.043 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.044 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.051 Session state does not function when running a script without `streamlit run`
# 2025-11-07 10:57:26.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.055 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.055 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.056 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.058 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.058 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.066 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.071 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.072 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.073 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.074 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.074 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.076 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.077 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.078 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.079 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.080 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.081 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.083 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.085 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.086 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.086 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.088 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.089 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.091 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.092 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.092 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.093 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.094 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.096 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.097 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.102 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.127 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.128 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.136 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 10:57:26.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
