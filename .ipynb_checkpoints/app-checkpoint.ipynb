# %%
import streamlit as st
import joblib

import numpy as np

#Load the model
@st.cache_resource
def load_model():
    return joblib.load("model.pkl")

model = load_model()

#App layout
st.set_page_config(page_title="Predicting Graduate/Dropout/Enrolled", layout="centered")
st.title("Predict Academic Outcome")
st.markdown("""
This tool helps to determine how an individuals academic outcome would be 
""")

# Form for user input
with st.form("sales_form"):
    col1, col2, col3 = st.columns(3)

    with col1:
        Course = st.selectbox(
        "Select Course",
        ["Architecture", "Computer Science", "Physics", "Accounting", "Civil Engineering"]
    )
    Age_at_enrollment = st.number_input(
        "Age at Enrollment", min_value=16, max_value=90, value=18
    )

    with col2:
        Tuition= st.selectbox("Payment Status", ["No", "Yes"])  
        Special_Needs= st.selectbox("Special Needs", ["No", "Yes"])
        
    with col3:
        Semster_Registeration = st.selectbox("1st Semester", ["Enrolled", "No record"])
        Curriculum_Units = st.selectbox("1st Semester", ["Approved", "Pending"])
        Semster_Registeration = st.selectbox("1st Semester", ["Enrolled", "No record"])
        Curriculum_Units = st.selectbox("2nd Semester", ["Approved", "Pending"])                              

    Acamedic_Status = st.selectbox("Academic Status", ["Graduate", "Dropout", "Enrolled"])

    submitted = st.form_submit_button("Predict")
                          
 #Predict
if submitted:
    Tuition = 1 if is_paid == "Yes" else 0
    SpecialNeeds = 1 if SpecialNeeds == "Yes" else 0
    Status_val = {"Enrolled": 0, "Graduate": 1, "Dropout": 2}[status]

    features = np.array([[Course, Age, Tuition, Special_Needs, Semster_Registeration, Curriculum_Units,  Acamedic_Status]])
    prediction = model.predicct(features)[0]

    st.success(f" Predicted Academic Outcome:{prediction:}")
# Out:
# 2025-11-03 08:54:58.207 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 08:54:59.199
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\Teninlanimi\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-11-03 08:54:59.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 08:54:59.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 08:54:59.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 08:54:59.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 11
#       7 @st.cache_resource
#       8 def load_model():
#       9     return joblib.load("model.pkl")
# ---> 11 model = load_model()
#      13 #App layout
#      14 st.set_page_config(page_title="Predicting Graduate/Dropout/Enrolled", layout="centered")
#
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\caching\cache_utils.py:219, in CachedFunc.__call__(self, *args, **kwargs)
#     216     else:
#     217         spinner_message = f"Running `{name}(...)`."
# --> 219 return self._get_or_create_cached_value(args, kwargs, spinner_message)
#
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\caching\cache_utils.py:261, in CachedFunc._get_or_create_cached_value(self, func_args, func_kwargs, spinner_message)
#     255 spinner_or_no_context = (
#     256     spinner(spinner_message, _cache=True)
#     257     if spinner_message is not None and not is_nested_cache_function
#     258     else contextlib.nullcontext()
#     259 )
#     260 with spinner_or_no_context:
# --> 261     return self._handle_cache_miss(cache, value_key, func_args, func_kwargs)
#
# File ~\anaconda3\Lib\site-packages\streamlit\runtime\caching\cache_utils.py:320, in CachedFunc._handle_cache_miss(self, cache, value_key, func_args, func_kwargs)
#     316 # We acquired the lock before any other thread. Compute the value!
#     317 with self._info.cached_message_replay_ctx.calling_cached_function(
#     318     self._info.func
#     319 ):
# --> 320     computed_value = self._info.func(*func_args, **func_kwargs)
#     322 # We've computed our value, and now we need to write it back to the cache
#     323 # along with any "replay messages" that were generated during value computation.
#     324 messages = self._info.cached_message_replay_ctx._most_recent_messages
#
# Cell In[5], line 9, in load_model()
#       7 @st.cache_resource
#       8 def load_model():
# ----> 9     return joblib.load("model.pkl")
#
# File ~\anaconda3\Lib\site-packages\joblib\numpy_pickle.py:650, in load(filename, mmap_mode)
#     648         obj = _unpickle(fobj)
#     649 else:
# --> 650     with open(filename, 'rb') as f:
#     651         with _read_fileobject(f, filename, mmap_mode) as fobj:
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model.pkl'
